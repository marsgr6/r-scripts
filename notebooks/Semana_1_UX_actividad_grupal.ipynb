# %% [markdown]
# **Actividad Sincrónica de Discusión - Semana 1**
#
# **Objetivo:**
# El objetivo de esta actividad es promover la comprensión y discusión colaborativa sobre conceptos fundamentales en estadística descriptiva, gráficos descriptivos, análisis exploratorio de datos y visualización avanzada en el contexto de la analítica de datos.
#
# **Instrucciones:**
# 1. **Formación de Grupos:**
#    - Los participantes deben formar grupos de discusión en la plataforma Teams. Cada grupo deberá tener al menos 3 integrantes.
#    - Cada grupo debe asignar a un moderador, quien será responsable de dirigir la discusión y mantener el orden.
#
# 2. **Discusión de Estadísticos Descriptivos:**
#    - Discutan qué es un estadístico y su importancia en la analítica de datos.
#    - Explore los estadísticos de centralidad y describan cuáles son y qué información proporcionan.
#    - Analicen los estadísticos de dispersión y expliquen qué describen.
#    - Aborden los estadísticos de orden y su utilidad en la descripción de datos.
#
# 3. **Discusión de Gráficos Descriptivos:**
#    - Examinen los gráficos univariados y discutan cuáles pueden utilizarse para describir datos categóricos y continuos.
#    - Analicen los gráficos multivariados y profundicen en los tipos de variables que pueden incorporarse.
#    - Identifiquen y expliquen nombres específicos de gráficos multivariados, así como su interpretación.
#
# 4. **Análisis Exploratorio de Datos:**
#    - Definan en qué consiste un análisis exploratorio de datos y por qué es crucial en el proceso de analítica de datos.
#    - Expliquen las herramientas utilizadas para llevar a cabo un análisis exploratorio y cómo estas contribuyen al entendimiento de los datos.
#
# 5. **Visualización Avanzada:**
#    - Introduzcan el concepto de visualización avanzada y discutan su importancia en la representación de datos complejos.
#    - Analicen qué tipos de gráficos y técnicas de visualización avanzada pueden ser utilizados en situaciones específicas.
#    - Compartan ejemplos de casos en los que la visualización avanzada ha proporcionado insights significativos.
#
# 6. **Intercambio de Conocimientos:**
#    - Cada grupo deberá compartir sus conclusiones y aprendizajes con el resto de la clase a través de un resumen breve.
#    - Animen a plantear preguntas y generar debate entre los grupos para enriquecer la comprensión de todos.
#
# 7. **Síntesis y Conclusiones:**
#    - En la sesión plenaria, se discutirán las principales conclusiones de cada grupo.
#    - Se destacarán las similitudes y diferencias en las interpretaciones y enfoques de los conceptos discutidos.
#
# **Dinámica:**
# La participación activa, la claridad en las explicaciones y la capacidad de síntesis serán bienvenidas. Se fomenta el debate y la colaboración entre los participantes para enriquecer la comprensión de los conceptos presentados, con especial énfasis en la visualización avanzada.
#
# - **Fuentes y recursos:**
#   - https://nbviewer.org/github/marsgr6/estadistica-ux/blob/main/descriptive_statistics.ipynb
#   - https://nbviewer.org/github/marsgr6/EN-online/blob/main/exploratory_data_analysis.ipynb
#   - https://nbviewer.org/github/marsgr6/estadistica-ux/blob/main/ux_visualization.ipynb
#
# Recuerden compartir ejemplos prácticos y experiencias que hayan encontrado en su experiencia profesional relacionados con estos conceptos. ¡La participación activa en esta discusión enriquecerá nuestro entendimiento colectivo!
#
# - **Anexo**
#
#   - Tipos de datos
#
# <img src="https://raw.githubusercontent.com/marsgr6/r-scripts/master/imgs/types_of_data.png" width="600"/>
#
#   - Escalas de medición
#
# <img src="https://raw.githubusercontent.com/marsgr6/r-scripts/master/imgs/levels_measurement.jpg" width="400"/>
#
#
# ### Distribuciones de probabilidad
#
# **Discuta los siguientes conceptos:**
#
# Recuerden compartir ejemplos prácticos y experiencias que hayan encontrado en su experiencia profesional relacionados con estos conceptos. ¡La participación activa en esta discusión enriquecerá nuestro entendimiento colectivo!
#
# - **Variables aleatorias y Distribuciones de probabilidad**
#   - Qué es una distribución de probabilidad.
#   - Por qué usamos distribuciones de probabilidad.
#   - Qué es una variable aleatoria discreta.
#   - De ejemplos de variables aleatorias discretas.
#
# - **PMF y CDF**
#   - Cuál es la definición de función de masa de probabilidad (PMF: Probability Mass Function).
#   - Cuál es la definición de función de distribución acumulada (CDF: Cumulative distribution function).
#   - **Opcional:** Cuál es la definición de la función cuantil.
#
# - **Valor esperado y varianza**
#
#   - Cuál es el valor esperado de una variable aleatoria discreta.
#     - Cómo interpreta el valor esperado de una v.a. discreta.
#
#   - Cuál es la varianza de una variable aleatoria discreta.
#     - Cómo interpreta el valor de la varianza v.a. discreta.
#
# - **Resuelva el siguiente ejercicio:**
#
# ![](https://raw.githubusercontent.com/marsgr6/r-scripts/master/imgs/tabla_pmf.png)
#
# - [Solución](https://colab.research.google.com/drive/1YC-bYWed78XBKfJykTOfaOfqS0MVJETz?usp=sharing)
#
# ### Distribuciones continuas
#
# - **Variables aleatorias y Distribuciones de probabilidad**
#   - Qué es una distribución de probabilidad.
#   - Por qué usamos distribuciones de probabilidad.
#   - Qué es una variable aleatoria continua.
#   - De ejemplos de variables aleatorias continuas.
#
# - **PDF y CDF**
#   - Cuál es la definición de función de densidad de probabilidad (PDF: Probability Density Function).
#   - Cuál es la definición de función de distribución acumulada (CDF: Cumulative distribution function).
#   - **Opcional:** Cuál es la definición de la función cuantil.
#
# - Cual es la probabilidad $P(X=x)$ en el caso continuo.
#
# - **Valor esperado y varianza**
#
#   - Cuál es el valor esperado de una variable aleatoria continua.
#     - Cómo interpreta el valor esperado de una v.a. continua.
#
#   - Cuál es la varianza de una variable aleatoria continua.
#     - Cómo interpreta el valor de la varianza v.a. continua.
#
#
# - **Distribuciones continuas importantes:**
#   - Describa la distribución uniforme y sus parámetros.
#   - Describa la distribución normal y sus parámetros.
#     - Describa el proceso de estandarización.
#     - Describa la regla 68-95-99.7.
#   - Describa la distribución exponencial y sus parámetros.
#
# - **Fuentes y recursos:**
#   - https://nbviewer.org/github/marsgr6/EN-online/blob/main/continuous_distributions.ipynb
#   - http://www.math.wm.edu/~leemis/chart/UDR/UDR.html

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=468d3185-d200-4f9b-a3ed-ece1001be9fc' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
