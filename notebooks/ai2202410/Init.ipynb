# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting networkx
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 58.1 MB/s eta 0:00:00
# Collecting ipywidgets==8.1.1
#   Downloading ipywidgets-8.1.1-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 10.0 MB/s eta 0:00:00
# Collecting scikit-image
#   Downloading scikit_image-0.19.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 61.1 MB/s eta 0:00:00
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 11.6 MB/s eta 0:00:00
# Collecting missingno==0.5.2
#   Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Collecting opencv-python==4.9.0.80
#   Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 28.1 MB/s eta 0:00:00
# Collecting comm>=0.1.3
#   Downloading comm-0.1.4-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: ipython>=6.1.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets==8.1.1->-r ./requirements.txt (line 2)) (7.34.0)
# Collecting jupyterlab-widgets~=3.0.9
#   Downloading jupyterlab_widgets-3.0.9-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.9/214.9 kB 39.7 MB/s eta 0:00:00
# Collecting widgetsnbextension~=4.0.9
#   Downloading widgetsnbextension-4.0.9-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 87.3 MB/s eta 0:00:00
# Requirement already satisfied: traitlets>=4.3.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets==8.1.1->-r ./requirements.txt (line 2)) (5.5.0)
# Requirement already satisfied: scipy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from missingno==0.5.2->-r ./requirements.txt (line 6)) (1.7.3)
# Requirement already satisfied: numpy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from missingno==0.5.2->-r ./requirements.txt (line 6)) (1.21.6)
# Requirement already satisfied: seaborn in /shared-libs/python3.7/py/lib/python3.7/site-packages (from missingno==0.5.2->-r ./requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: matplotlib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from missingno==0.5.2->-r ./requirements.txt (line 6)) (3.5.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-image->-r ./requirements.txt (line 3)) (9.2.0)
# Collecting imageio>=2.4.1
#   Downloading imageio-2.31.2-py3-none-any.whl (313 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.2/313.2 kB 41.5 MB/s eta 0:00:00
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2021.11.2-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 kB 49.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from scikit-image->-r ./requirements.txt (line 3)) (21.3)
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 102.4 MB/s eta 0:00:00
# Requirement already satisfied: pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r ./requirements.txt (line 2)) (2.13.0)
# Requirement already satisfied: pickleshare in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r ./requirements.txt (line 2)) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r ./requirements.txt (line 2)) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /root/venv/lib/python3.7/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r ./requirements.txt (line 2)) (47.1.0)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r ./requirements.txt (line 2)) (0.17.2)
# Requirement already satisfied: backcall in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r ./requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r ./requirements.txt (line 2)) (0.1.6)
# Requirement already satisfied: decorator in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r ./requirements.txt (line 2)) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=6.1.0->ipywidgets==8.1.1->-r ./requirements.txt (line 2)) (3.0.31)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from packaging>=20.0->scikit-image->-r ./requirements.txt (line 3)) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->missingno==0.5.2->-r ./requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->missingno==0.5.2->-r ./requirements.txt (line 6)) (4.37.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->missingno==0.5.2->-r ./requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib->missingno==0.5.2->-r ./requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: pandas>=0.25 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from seaborn->missingno==0.5.2->-r ./requirements.txt (line 6)) (1.2.5)
# Requirement already satisfied: typing_extensions in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from seaborn->missingno==0.5.2->-r ./requirements.txt (line 6)) (4.4.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.1.1->-r ./requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas>=0.25->seaborn->missingno==0.5.2->-r ./requirements.txt (line 6)) (2022.5)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets==8.1.1->-r ./requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets==8.1.1->-r ./requirements.txt (line 2)) (0.2.5)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib->missingno==0.5.2->-r ./requirements.txt (line 6)) (1.16.0)
# Installing collected packages: xlrd, widgetsnbextension, tifffile, PyWavelets, opencv-python, networkx, jupyterlab-widgets, imageio, comm, scikit-image, ipywidgets, missingno
# Successfully installed PyWavelets-1.3.0 comm-0.1.4 imageio-2.31.2 ipywidgets-8.1.1 jupyterlab-widgets-3.0.9 missingno-0.5.2 networkx-2.6.3 opencv-python-4.9.0.80 scikit-image-0.19.3 tifffile-2021.11.2 widgetsnbextension-4.0.9 xlrd-2.0.1
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cce3455d-da08-4c10-a6fe-39f2a30c6a51' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
