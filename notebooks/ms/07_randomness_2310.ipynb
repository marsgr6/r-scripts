# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
directions = [-1, 1]
step_size = 0.1

walk = [0]
for i in range(10):
    walk += [walk[-1] + np.random.choice(directions)*step_size]
    #if walk[-1] == 0:
    if np.isclose(walk[-1], 0):
        print("Returned!")
plt.plot(walk)
# Out:
# Returned!
# Returned!
# Returned!

# %%
0.1+0.1+0.1==0.3
# Out:
# False

# %% [markdown]
# - Check: https://anaconda.org/marsgr6/deberes_ms_201920/notebook

# %%
import string

persons = 10
letters = np.array(list(string.ascii_lowercase[:persons]))
envelopes = np.array(list(string.ascii_lowercase[:persons]))

matches = []
for i in range(1000):
    np.random.shuffle(letters)
    matches += [(letters==envelopes).sum()]

np.unique(matches, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), array([368, 363, 180,  69,  18,   1,   1]))

# %%
word = list('KITCHEN')

sims = 100
found = []
for i in range(sims):
    np.random.shuffle(word)
    found += [''.join(word).find('KIT') is not -1]
np.array(found).sum()/sims
# Out:
# 0.0

# %%
'KITCHEN'.find('CHI')
# Out:
# -1

# %% [markdown]
# ### Independent versus dependent random numbers
#
# - Generate a sequence of NN independent random variables with values 0 or 1 and print out this sequence without space between the numbers (i.e., as 001011010110111010).
#
# - The purpose now is to generate random zeros and ones that are dependent. If the last generated number was 0, the probability of generating a new 0 is p and a new 1 is 1−p. Conversely, if the last generated was 1, the probability of generating a new 1 is p and a new 0 is 1−p. Since the new value depends on the last one, we say the variables are dependent. Implement this algorithm in a function returning an array of NN zeros and ones. Print out this array in the condense format as described above.
#
# - Choose N=80 and try the probabilities p=0.5, p=0.8 and p=0.9. Can you by visual inspection of the output characterize the differences between sequences of independent and dependent random variables?

# %%
from scipy.stats import bernoulli

p = 0.5

X = [bernoulli.rvs(p)]

N = 80

for i in range(N):
    if X[-1] == 0:
        X += [bernoulli.rvs(1-p)]
    else:
        X += [bernoulli.rvs(p)]

plt.plot(X)

# %% [markdown]
# - Check: http://bit-player.org/wp-content/extras/bph-publications/AmSci-1998-07-Hayes-self-avoidance.pdf

# %%
def sumar(a, b):
    return a[0] + b[0], a[1] + b[1]

directions = np.array([(1,0), (-1,0), (0,1), (0,-1)])

walk = [(0, 0)]

for i in range(100):
    possible_directions = [sumar(walk[-1], di) for di in directions]
    possible_moves = list(set(possible_directions) - set(walk))

    if not len(possible_moves):
        break
    move = np.random.choice(len(possible_moves))
    walk += [possible_moves[move]]

walk = np.array(walk)
plt.plot(walk[:,0], walk[:,1])

# %%
len(walk)
# Out:
# 39

# %%
walk = [(0, 0), (1, 0)]

possible_directions = [sumar(walk[-1], di) for di in directions]

move = np.random.choice(len(possible_directions))
possible_directions, possible_directions[move]
# Out:
# ([(2, 0), (0, 0), (1, 1), (1, -1)], (0, 0))

# %%
possible_moves = list(set(possible_directions) - set(walk))
# Out:
# {(1, -1), (1, 1), (2, 0)}

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=6270f206-ff88-4533-afc5-e2a8c2de37fb' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
