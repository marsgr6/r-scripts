# %% [markdown]
# # Introduction to Python 3 for Data Analytics
#
# ### Course audience
#
# This workshop is for those who have some experience in using a scripting language (not mandatory) and want to try Python. It is assumed that you can edit a text file using your favorite editor, and be able to execute your script file on the command line of a shell.
#
# ### Course content (general topics)
#
# 1. Introduction to Python 3 and scientific computation
#     - Language basics: data types, control sentences, functions and modules
#     - __[numpy](http://www.numpy.org)__ - library that provides lots of linear algebra functionality and numerical computation
#     - __[SciPy](https://www.scipy.org)__ - ecosystem of open-source software for mathematics, science, and engineering
#     - __[matplotlib](https://matplotlib.org)__ - a Python 2D plotting library
# 2. Data science:
#     - An __[informal introduction](https://anaconda.org/marsgr6/data_science/notebook)__
#     - __[pandas](https://pandas.pydata.org)__ - library providing high-performance, easy-to-use data structures and data analysis tools
#     - __[seaborn](https://seaborn.pydata.org/index.html)__ - plots and graphs for data visualization (EDA)
#     - __[scikit-learn](http://scikit-learn.org/stable/)__ - provides machine learning models and tools
#     - __[tensorflow](https://www.tensorflow.org/)__, __[pytorch](http://pytorch.org/)__, __[keras](https://keras.io/)__ - libraries for deep learning*
#
# See also __[this link on quora](https://www.quora.com/What-are-some-Python-libraries-and-their-uses-I-have-learned-basic-Python-language-so-which-libraries-can-I-start-learning-that-can-fetch-me-a-good-job)__.
#
# ### Software requirements
#
# Download __[Anaconda](https://www.anaconda.com/download/)__ Python and follow __[these instructions](https://medium.com/@GalarnykMichael/install-python-on-windows-anaconda-c63c7c3d1444)__.
#
# Get used with __[Jupyter notebooks](https://www.datacamp.com/community/tutorials/tutorial-jupyter-notebook?utm_medium=fb%2Cig%2Can%2Cms-all&utm_source=fb_paid&utm_campaign=smartly_registered&utm_id=59dd10bb839578444a0ab9af)__.
#
# ### Resources
#
# - FEUP Knowledge Extraction and Machine Learning: https://web.fe.up.pt/~ec/index.html
# - You can also find sources and resources on each notebook.
#
# ### Please do fill out the following __[survey](https://docs.google.com/forms/d/e/1FAIpQLSckHDNG7L_1FFWb9xT-AHtGTRnai9ACZe57pJQAA1hXdgNDHw/viewform?usp=sf_link)__
#
# ### Course Sessions (2 hours classroom + 2 hours autonomous learning)
#
# The sessions will be predominantly practical and 2 hours __[live coding sessions](https://en.wikipedia.org/wiki/Live_coding)__ with 2 hours of autonomous or group programming.
#
# | Session | Topics |
# |:----------:|:----------|
# | __[1a](https://goo.gl/fLpgjG)__     | Introducción al curso |
# | 1b     | __[Anaconda](https://www.anaconda.com/download/)__ installation - The Most Popular Python Data Science Platform |
# | __[1c](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/intro_python3.ipynb)__     | An informal introduction to Python and the interpreter |
# | __[1d](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/intro_python3.ipynb)__     | Data types, variables, compound data types |
# | __[2a](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/estructuras_de_control_python.ipynb)__     | Operators and control sentences: decisions and loops |
# | __[2b](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/funciones_python.ipynb)__     | Functions in Python, __[Practical work](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/exercises.ipynb)__ |
# | __[2c](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/funciones_python.ipynb)__     | __[Scripts and modules](https://drive.google.com/drive/folders/0B-dmEvN59Z2ZLWtFbTJfLVZQVDg)__: import and utilize a module |
# | 3a     | Computing with __[NumPy](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/numpy.ipynb)__ and SciPy and render simple plots with __[matplotlib](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/matplotlib.ipynb)__ |
# | 4a     | Write a simple class and access methods and attributes |
# | __[4b](https://trinket.io/python/22f06067e6)__     | __[Turtles](http://pythonturtle.org)__ in Python |
# | __[5a](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/simulation_home.ipynb)__     | Modeling and __[Simulation](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/simulation_home.ipynb)__ with Python |
# | __[6a](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/pandas_python.ipynb)__     | Data tidying with __[pandas](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/pandas_python.ipynb)__ |
# | __[7a](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/descriptive_statistics.ipynb)__     | Exploratory Data Analysis (EDA) with __[seaborn](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/seaborn.ipynb)__, __[AQ example](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/eda_python.ipynb)__ |
# | __[8a](https://www.dropbox.com/s/inoq7v74yc5v3mc/Classification_and_regression.pdf?dl=0)__     | Introduction to machine learning: classification and regression |
# | 8b     | Linear models: __[simple](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/linear_regression_py.ipynb)__, __[multiple](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/multiple_linear_regression_py.ipynb)__ linear and __[logistic](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/logistic_regression_py.ipynb)__ regression |
# | 9a     | __[Classification](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/random_forest_scikit_learn.ipynb)__ and __[Regression](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/neural_networks_scikit_learn.ipynb)__ with scikit-learn, __[dtrees](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/decision_trees.ipynb)__, __[mlp](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/mlp.ipynb)__ |
# | 10a     | __[Clustering](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/clustering.ipynb)__ |
# | __[10b](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/graph_search.ipynb)__     | Network analysis with __[networkx](https://nbviewer.org/github/marsgr6/r-scripts/blob/master/notebooks/python_intro_ds/graph_search.ipynb)__ |
